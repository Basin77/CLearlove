# %%
import pandas as pd
import numpy as np
pd.options.display.max_rows = 400

artist=pd.read_csv('C:/Users/lll/Desktop/artist_data.csv', delimiter=",", encoding='utf-8')
artist = artist.rename(columns={'name':'artist'})
artwork=pd.read_csv('C:/Users/lll/Desktop/artwork_data.csv', low_memory=False, delimiter=",", encoding='utf-8')
DB=pd.merge(artist, artwork, on='artist')
DB
# Out:
#         id_x                  artist  gender      dates  yearOfBirth  \
# 0      10093  Abakanowicz, Magdalena  Female  born 1930       1930.0
# 1      10093  Abakanowicz, Magdalena  Female  born 1930       1930.0
# 2      10093  Abakanowicz, Magdalena  Female  born 1930       1930.0
# 3      10093  Abakanowicz, Magdalena  Female  born 1930       1930.0
# 4          0     Abbey, Edwin Austin    Male  1852–1911       1852.0
# ...      ...                     ...     ...        ...          ...
# 69308  12542         Zorio, Gilberto    Male  born 1944       1944.0
# 69309   2186              Zox, Larry    Male  born 1936       1936.0
# 69310    621   Zuccarelli, Francesco    Male  1702–1788       1702.0
# 69311   2187        Zuloaga, Ignacio    Male  1870–1945       1870.0
# 69312   2188         Zyw, Aleksander    Male  1905–1995       1905.0
#
#        yearOfDeath                 placeOfBirth            placeOfDeath  \
# ...

# %%
median_height=DB.groupby('year')[['height']].median().reset_index()
median_height
count.to_csv('DB', encoding='utf-8', index=False)
# Out:
#          year  height
# 0        1545   410.0
# 1        1557   483.0
# 2        1563   302.0
# 3        1565   619.0
# 4        1569   483.0
# 5        1573   461.0
# 6        1576   464.0
# 7        1586   451.0
# 8        1592   851.0
# 9        1594  1508.0
# 10       1595   760.0
# 11       1596   297.5
# 12       1600  1723.0
# 13       1605   806.0
# 14       1610   446.0
# 15       1615   610.0
# 16       1619   819.0
# 17       1620  1270.0
# 18       1623  1251.0
# 19       1625   740.5
# 20       1628   630.0
# 21       1629   324.0
# 22       1630   396.0
# 23       1633  1276.0
# 24       1635   825.5
# 25       1636  2060.5
# 26       1637   183.0
# 27       1638   837.0
# 28       1639   687.0
# 29       1640   608.0
# 30       1642  1270.0
# 31       1644   635.0
# 32       1645   762.0
# 33       1646   811.0
# 34       1647    74.0
# 35       1648  1042.0
# 36       1650  1044.5
# 37       1654  1598.0
# 38       1655  1111.0
# 39       1658   171.0
# ...

# %%
ax = median_height.plot(kind='scatter', x='year', y='height', color='red')

# %%
I want to study the change in the size of the artwork over time. I calculate the height data as a function of year 
to get the median to represent the height of the artwork over the course of each year. The data is then presented 
with the year as the horizontal coordinate and the height as the vertical coordinate.I know this is not a good way 
to show the size, the height data cannot be used alone. I would like to ask how to do the multiplication of the two 
columns of data in the CSV file. Also there is a more tricky problem, the data in the height and width columns are 
displayed as objects, which cannot output the correct result when doing the calculation, how to change the format of 
this column data is the main problem I am facing.Besides that, I had another problem. It was a discovery after I opened 
the artist_data file in excel format, made some changes and saved it. I can't do anything with this file in python 
anymore, and I can't even open this csv file. I would like to ask why this is.
# Out:
#   Input In [46]
#     I want to study the change in the size of the artwork over time.
#       ^
# SyntaxError: invalid syntax
